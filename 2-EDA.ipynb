# %% [markdown]
# ## codata-nuppa
#
# Tratamento e limpeza dos dados para o dashboard do Nuppa
#
# This notebook contains basic statistical analysis and visualization of the data.
#
# ### Data Sources
# - summary : Processed file from notebook 1-Data_Prep
#
# ### Changes
# - 11-28-2024 : Started project

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ### File Locations

# %%
today = datetime.today()
in_file_prd = Path.cwd() / "data" / "processed" / f"summary_produtos.pkl"
in_file_blt = Path.cwd() / "data" / "processed" / f"summary_Tabela NUPPA 80.pkl"
report_dir = Path.cwd() / "reports"
report_file = report_dir / f"nuppa_{in_file_blt.stem.split()[-1]}-2022.xlsx"

# %%
df_prd = pd.read_pickle(in_file_prd)
df_blt = pd.read_pickle(in_file_blt)

display(df_prd.dtypes)
display(df_blt.dtypes)
# Out:
# PRODUTO            object
# UNIDADE MEDIDA     object
# QTD UNI MED       float64
# DESC UNI MED       object
# GRUPO              object
# URL IMAGEM         object
# dtype: object
# PRODUTO            object
# UNIDADE MEDIDA     object
# QTD UNI MED       float64
# DESC UNI MED       object
# COMUM             float64
# MINIMO            float64
# MAXIMO            float64
# MEDIA             float64
# MEDIANA           float64
# COLETA             object
# dtype: object

# %% [markdown]
# ### Perform Data Analysis

# %%
df_blt['COLETA'] = pd.to_datetime(df_blt['COLETA'], format='%d/%m/%Y', errors='coerce')
df_blt['COLETA'] = df_blt['COLETA'].dt.strftime('%d/%m/%Y')
df_blt
# Out:
#                    PRODUTO  UNIDADE MEDIDA  QTD UNI MED DESC UNI MED  COMUM  \
# 0                   ACELGA  12.0  UNIDADES         12.0     UNIDADES   60.0
# 1                   AGRIÃO  12.0  UNIDADES         12.0     UNIDADES    NaN
# 2         ALFACE AMERICANA  12.0  UNIDADES         12.0     UNIDADES    NaN
# 3            ALFACE CRESPA  12.0  UNIDADES         12.0     UNIDADES    NaN
# 4              ALFACE LISA  12.0  UNIDADES         12.0     UNIDADES    NaN
# 5                 ALMEIRÃO  12.0  UNIDADES         12.0     UNIDADES    NaN
# 6   BRÓCOLOS NINJA/JAPONÊS  12.0  UNIDADES         12.0     UNIDADES   60.0
# 7          BRÓCOLOS RAMOSO  12.0  UNIDADES         12.0     UNIDADES   72.0
# 8           COUVE-MANTEIGA  12.0  UNIDADES         12.0     UNIDADES   24.0
# 9               COUVE-FLOR  12.0  UNIDADES         12.0     UNIDADES    NaN
# 10                ESCAROLA  12.0  UNIDADES         12.0     UNIDADES    NaN
# 11               ESPINAFRE  12.0  UNIDADES         12.0     UNIDADES    NaN
# 12                RABANETE     12.0  MAÇOS         12.0        MAÇOS    NaN
# 13            REPOLHO ROXO  12.0  UNIDADES         12.0     UNIDADES    NaN
# 14           REPOLHO VERDE  12.0  UNIDADES         12.0     UNIDADES   30.0
# 15                 RÚCULA   12.0  UNIDADES         12.0     UNIDADES   54.0
# 16               CEBOLINHA         0.5  KG          0.5           KG    5.0
# 17                 COENTRO         2.0  KG          2.0           KG   20.0
# 18                SALSINHA         2.0  KG          2.0           KG   30.0
# 19         ABOBORÁ CABOTIÁ        30.0  KG         30.0           KG   80.0
# 20      ABOBRINHA ITALIANA        17.0  KG         17.0           KG    NaN
# 21             BATATA-DOCE        18.0  KG         18.0           KG   65.0
# 22         BERINJELA COMUM        10.0  KG         10.0           KG   55.0
# 23      BERINJELA JAPONESA        10.0  KG         10.0           KG    NaN
# 24               BETERRABA        20.0  KG         20.0           KG   60.0
# 25                 CENOURA        18.0  KG         18.0           KG   50.0
# 26                 CHUCHU         18.0  KG         18.0           KG   40.0
# 27                    JILÓ        17.0  KG         17.0           KG  110.0
# 28                MANDIOCA        18.0  KG         18.0           KG    NaN
# 29            PEPINO COMUM        17.0  KG         17.0           KG   50.0
# 30         PEPINO JAPONÊS         17.0  KG         17.0           KG   60.0
# 31          PIMENTÃO VERDE        10.0  KG         10.0           KG   55.0
# 32                  QUIABO        12.0  KG         12.0           KG  170.0
# 33           TOMATE DÉBORA        17.0  KG         17.0           KG   60.0
# 34          VAGEM MACARRÃO        17.0  KG         17.0           KG   50.0
# 35              CAQUI FUYU        10.0  KG         10.0           KG    NaN
# 36            CAQUI GUIMBO        10.0  KG         10.0           KG    NaN
# 37        CAQUI RAMA FORTE        10.0  KG         10.0           KG    NaN
# 38                  GOIABA        10.0  KG         10.0           KG    NaN
# 39         MEXERICA POLKAN        22.0  KG         22.0           KG    NaN
#
#     MINIMO  MAXIMO       MEDIA  MEDIANA      COLETA
# 0     48.0    60.0   56.000000     60.0  22/11/2024
# 1     84.0    90.0   87.000000     87.0  22/11/2024
# 2     45.0    60.0   51.000000     48.0  22/11/2024
# 3     30.0    36.0   33.666667     35.0  22/11/2024
# 4     35.0    36.0   35.500000     35.5  22/11/2024
# 5     66.0    72.0   69.000000     69.0  22/11/2024
# 6     60.0    78.0   66.000000     60.0  22/11/2024
# 7     72.0    84.0   76.000000     72.0  22/11/2024
# 8     18.0    24.0   22.000000     24.0  22/11/2024
# 9     72.0    84.0   78.000000     78.0  22/11/2024
# 10    24.0    36.0   31.666667     35.0  22/11/2024
# 11    72.0    84.0   78.000000     78.0  22/11/2024
# 12    60.0    78.0   70.000000     72.0  22/11/2024
# 13    40.0    72.0   56.000000     56.0  22/11/2024
# 14    30.0    35.0   31.666667     30.0  22/11/2024
# 15    54.0    60.0   56.000000     54.0  22/11/2024
# 16     5.0     5.0    5.000000      5.0  22/11/2024
# 17    20.0    20.0   20.000000     20.0  22/11/2024
# 18    25.0    30.0   28.333333     30.0  22/11/2024
# 19    75.0    80.0   78.333333     80.0  22/11/2024
# 20    40.0    80.0   58.333333     57.5  22/11/2024
# 21    45.0    70.0   60.000000     65.0  22/11/2024
# 22    50.0    60.0   54.166667     55.0  22/11/2024
# 23    90.0   120.0  105.000000    105.0  22/11/2024
# 24    50.0    65.0   58.333333     60.0  22/11/2024
# 25    50.0    65.0   56.666667     57.5  22/11/2024
# 26    35.0    50.0   41.666667     40.0  22/11/2024
# 27   110.0   130.0  118.000000    120.0  22/11/2024
# 28    70.0    70.0   70.000000     70.0  22/11/2024
# 29    40.0    50.0   47.500000     50.0  22/11/2024
# 30    45.0    70.0   58.333333     60.0  22/11/2024
# 31    40.0    55.0   49.166667     50.0  22/11/2024
# 32   140.0   180.0  163.333333    165.0  22/11/2024
# 33    50.0    90.0   65.833333     62.5  22/11/2024
# 34    50.0    80.0   58.000000     50.0  22/11/2024
# 35     NaN     NaN         NaN      NaN  22/11/2024
# 36     NaN     NaN         NaN      NaN  22/11/2024
# 37     NaN     NaN         NaN      NaN  22/11/2024
# 38    70.0    70.0   70.000000     70.0  22/11/2024
# 39     NaN     NaN         NaN      NaN  22/11/2024

# %%
df_blt['PRODUTO'] = df_blt['PRODUTO'].str.strip()

# %%
df_prd
# Out:
#                    PRODUTO UNIDADE MEDIDA  QTD UNI MED DESC UNI MED  \
# 0          ABOBORÁ CABOTIÁ          30 KG         30.0           KG
# 1       ABOBRINHA ITALIANA          17 KG         17.0           KG
# 2                   ACELGA    12 UNIDADES         12.0     UNIDADES
# 3                   AGRIÃO    12 UNIDADES         12.0     UNIDADES
# 4         ALFACE AMERICANA    12 UNIDADES         12.0     UNIDADES
# 5            ALFACE CRESPA    12 UNIDADES         12.0     UNIDADES
# 6              ALFACE LISA    12 UNIDADES         12.0     UNIDADES
# 7                 ALMEIRÃO    12 UNIDADES         12.0     UNIDADES
# 8              BATATA-DOCE          18 KG         18.0           KG
# 9          BERINJELA COMUM          10 KG         10.0           KG
# 10      BERINJELA JAPONESA          10 KG         10.0           KG
# 11               BETERRABA          20 KG         20.0           KG
# 12  BRÓCOLOS NINJA/JAPONÊS    12 UNIDADES         12.0     UNIDADES
# 13         BRÓCOLOS RAMOSO    12 UNIDADES         12.0     UNIDADES
# 14              CAQUI FUYU          10 KG         10.0           KG
# 15            CAQUI GUIMBO          10 KG         10.0           KG
# 16        CAQUI RAMA FORTE          10 KG         10.0           KG
# 17               CEBOLINHA    MAÇO 0,5 KG          0.5           KG
# 18                 CENOURA          18 KG         18.0           KG
# 19                  CHUCHU          18 KG         18.0           KG
# 20                 COENTRO      MAÇO 2 KG          2.0           KG
# 21              COUVE-FLOR    12 UNIDADES         12.0     UNIDADES
# 22          COUVE-MANTEIGA    12 UNIDADES         12.0     UNIDADES
# 23                ESCAROLA    12 UNIDADES         12.0     UNIDADES
# 24               ESPINAFRE    12 UNIDADES         12.0     UNIDADES
# 25                  GOIABA          10 KG         10.0           KG
# 26                    JILÓ          17 KG         17.0           KG
# 27                MANDIOCA          18 KG         18.0           KG
# 28         MEXERICA POLKAN          22 KG         22.0           KG
# 29            PEPINO COMUM          17 KG         17.0           KG
# 30          PEPINO JAPONÊS          17 KG         17.0           KG
# 31          PIMENTÃO VERDE          10 KG         10.0           KG
# 32                  QUIABO          12 KG         12.0           KG
# 33                RABANETE       12 MAÇOS         12.0        MAÇOS
# 34            REPOLHO ROXO    12 UNIDADES         12.0     UNIDADES
# 35           REPOLHO VERDE    12 UNIDADES         12.0     UNIDADES
# 36                  RÚCULA    12 UNIDADES         12.0     UNIDADES
# 37                SALSINHA      MAÇO 2 KG          2.0           KG
# 38           TOMATE DÉBORA          17 KG         17.0           KG
# 39          VAGEM MACARRÃO          17 KG         17.0           KG
#
#                                                 GRUPO  \
# 0   GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 1   GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 2      GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 3      GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 4      GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 5      GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 6      GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 7      GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 8   GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 9   GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 10  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 11  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 12     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 13     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 14                                   GRUPO D - FRUTAS
# 15                                   GRUPO D - FRUTAS
# 16                                   GRUPO D - FRUTAS
# 17      GRUPO B - HORTALIÇAS CONDIMENTARES (TEMPEROS)
# 18  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 19  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 20      GRUPO B - HORTALIÇAS CONDIMENTARES (TEMPEROS)
# 21     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 22     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 23     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 24     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 25                                   GRUPO D - FRUTAS
# 26  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 27  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 28                                   GRUPO D - FRUTAS
# 29  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 30  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 31  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 32  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 33     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 34     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 35     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 36     GRUPO A - VERDURAS (FOLHOSAS, FLORES E HASTES)
# 37      GRUPO B - HORTALIÇAS CONDIMENTARES (TEMPEROS)
# 38  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
# 39  GRUPO C - HORTALIÇAS LEGUMES (LEGUMINOSAS (VAG...
#
#                                            URL IMAGEM
# 0   https://lh3.googleusercontent.com/pw/AP1GczNjQ...
# 1   https://lh3.googleusercontent.com/pw/AP1GczMQu...
# 2   https://lh3.googleusercontent.com/pw/AP1GczM4r...
# 3   https://lh3.googleusercontent.com/pw/AP1GczNq9...
# 4   https://lh3.googleusercontent.com/pw/AP1GczOJs...
# 5   https://lh3.googleusercontent.com/pw/AP1GczMEk...
# 6   https://lh3.googleusercontent.com/pw/AP1GczOxK...
# 7   https://lh3.googleusercontent.com/pw/AP1GczNhl...
# 8   https://lh3.googleusercontent.com/pw/AP1GczNyu...
# 9   https://lh3.googleusercontent.com/pw/AP1GczN6g...
# 10  https://lh3.googleusercontent.com/pw/AP1GczNOq...
# 11  https://lh3.googleusercontent.com/pw/AP1GczOC2...
# 12  https://lh3.googleusercontent.com/pw/AP1GczNIZ...
# 13  https://lh3.googleusercontent.com/pw/AP1GczOMO...
# 14  https://lh3.googleusercontent.com/pw/AP1GczMVG...
# 15  https://lh3.googleusercontent.com/pw/AP1GczMCf...
# 16  https://lh3.googleusercontent.com/pw/AP1GczOwb...
# 17  https://lh3.googleusercontent.com/pw/AP1GczOxd...
# 18  https://lh3.googleusercontent.com/pw/AP1GczMhD...
# 19  https://lh3.googleusercontent.com/pw/AP1GczOj-...
# 20  https://lh3.googleusercontent.com/pw/AP1GczMbk...
# 21  https://lh3.googleusercontent.com/pw/AP1GczM5r...
# 22  https://lh3.googleusercontent.com/pw/AP1GczMsF...
# 23  https://lh3.googleusercontent.com/pw/AP1GczNpU...
# 24  https://lh3.googleusercontent.com/pw/AP1GczMJ4...
# 25  https://lh3.googleusercontent.com/pw/AP1GczPsh...
# 26  https://lh3.googleusercontent.com/pw/AP1GczPrY...
# 27  https://lh3.googleusercontent.com/pw/AP1GczPE4...
# 28  https://lh3.googleusercontent.com/pw/AP1GczN1U...
# 29  https://lh3.googleusercontent.com/pw/AP1GczPPK...
# 30  https://lh3.googleusercontent.com/pw/AP1GczPZT...
# 31  https://lh3.googleusercontent.com/pw/AP1GczMCy...
# 32  https://lh3.googleusercontent.com/pw/AP1GczM8r...
# 33  https://lh3.googleusercontent.com/pw/AP1GczOHo...
# 34  https://lh3.googleusercontent.com/pw/AP1GczPbC...
# 35  https://lh3.googleusercontent.com/pw/AP1GczPcc...
# 36  https://lh3.googleusercontent.com/pw/AP1GczMlf...
# 37  https://lh3.googleusercontent.com/pw/AP1GczMy0...
# 38  https://lh3.googleusercontent.com/pw/AP1GczOEO...
# 39  https://lh3.googleusercontent.com/pw/AP1GczMyH...

# %%
df_prd['PRODUTO'] = df_prd['PRODUTO'].str.strip()

# %%
# Merge dos dataframes com base no campo 'PRODUTO'
comparacao = pd.merge(
    df_blt[['PRODUTO', 'QTD UNI MED', 'DESC UNI MED']],
    df_prd[['PRODUTO', 'QTD UNI MED', 'DESC UNI MED']],
    on='PRODUTO',
    suffixes=('_boletim', '_produtos'),
    how='left'
)

# %%
comparacao
# Out:
#                    PRODUTO  QTD UNI MED_boletim DESC UNI MED_boletim  \
# 0                   ACELGA                 12.0             UNIDADES
# 1                   AGRIÃO                 12.0             UNIDADES
# 2         ALFACE AMERICANA                 12.0             UNIDADES
# 3            ALFACE CRESPA                 12.0             UNIDADES
# 4              ALFACE LISA                 12.0             UNIDADES
# 5                 ALMEIRÃO                 12.0             UNIDADES
# 6   BRÓCOLOS NINJA/JAPONÊS                 12.0             UNIDADES
# 7          BRÓCOLOS RAMOSO                 12.0             UNIDADES
# 8           COUVE-MANTEIGA                 12.0             UNIDADES
# 9               COUVE-FLOR                 12.0             UNIDADES
# 10                ESCAROLA                 12.0             UNIDADES
# 11               ESPINAFRE                 12.0             UNIDADES
# 12                RABANETE                 12.0                MAÇOS
# 13            REPOLHO ROXO                 12.0             UNIDADES
# 14           REPOLHO VERDE                 12.0             UNIDADES
# 15                  RÚCULA                 12.0             UNIDADES
# 16               CEBOLINHA                  0.5                   KG
# 17                 COENTRO                  2.0                   KG
# 18                SALSINHA                  2.0                   KG
# 19         ABOBORÁ CABOTIÁ                 30.0                   KG
# 20      ABOBRINHA ITALIANA                 17.0                   KG
# 21             BATATA-DOCE                 18.0                   KG
# 22         BERINJELA COMUM                 10.0                   KG
# 23      BERINJELA JAPONESA                 10.0                   KG
# 24               BETERRABA                 20.0                   KG
# 25                 CENOURA                 18.0                   KG
# 26                  CHUCHU                 18.0                   KG
# 27                    JILÓ                 17.0                   KG
# 28                MANDIOCA                 18.0                   KG
# 29            PEPINO COMUM                 17.0                   KG
# 30          PEPINO JAPONÊS                 17.0                   KG
# 31          PIMENTÃO VERDE                 10.0                   KG
# 32                  QUIABO                 12.0                   KG
# 33           TOMATE DÉBORA                 17.0                   KG
# 34          VAGEM MACARRÃO                 17.0                   KG
# 35              CAQUI FUYU                 10.0                   KG
# 36            CAQUI GUIMBO                 10.0                   KG
# 37        CAQUI RAMA FORTE                 10.0                   KG
# 38                  GOIABA                 10.0                   KG
# 39         MEXERICA POLKAN                 22.0                   KG
#
#     QTD UNI MED_produtos DESC UNI MED_produtos
# 0                   12.0              UNIDADES
# 1                   12.0              UNIDADES
# 2                   12.0              UNIDADES
# 3                   12.0              UNIDADES
# 4                   12.0              UNIDADES
# 5                   12.0              UNIDADES
# 6                   12.0              UNIDADES
# 7                   12.0              UNIDADES
# 8                   12.0              UNIDADES
# 9                   12.0              UNIDADES
# 10                  12.0              UNIDADES
# 11                  12.0              UNIDADES
# 12                  12.0                 MAÇOS
# 13                  12.0              UNIDADES
# 14                  12.0              UNIDADES
# 15                  12.0              UNIDADES
# 16                   0.5                    KG
# 17                   2.0                    KG
# 18                   2.0                    KG
# 19                  30.0                    KG
# 20                  17.0                    KG
# 21                  18.0                    KG
# 22                  10.0                    KG
# 23                  10.0                    KG
# 24                  20.0                    KG
# 25                  18.0                    KG
# 26                  18.0                    KG
# 27                  17.0                    KG
# 28                  18.0                    KG
# 29                  17.0                    KG
# 30                  17.0                    KG
# 31                  10.0                    KG
# 32                  12.0                    KG
# 33                  17.0                    KG
# 34                  17.0                    KG
# 35                  10.0                    KG
# 36                  10.0                    KG
# 37                  10.0                    KG
# 38                  10.0                    KG
# 39                  22.0                    KG

# %%
# Verificação de correspondência entre os campos
comparacao['QTD_CORRESPONDE'] = comparacao['QTD UNI MED_produtos'] == comparacao['QTD UNI MED_boletim']

# Normalizando as colunas antes da comparação
comparacao['DESC UNI MED_produtos'] = comparacao['DESC UNI MED_produtos'].str.strip().str.upper()
comparacao['DESC UNI MED_boletim'] = comparacao['DESC UNI MED_boletim'].str.strip().str.upper()

comparacao['DESC_CORRESPONDE'] = comparacao['DESC UNI MED_produtos'] == comparacao['DESC UNI MED_boletim']

# %%
comparacao
# Out:
#                    PRODUTO  QTD UNI MED_boletim DESC UNI MED_boletim  \
# 0                   ACELGA                 12.0             UNIDADES
# 1                   AGRIÃO                 12.0             UNIDADES
# 2         ALFACE AMERICANA                 12.0             UNIDADES
# 3            ALFACE CRESPA                 12.0             UNIDADES
# 4              ALFACE LISA                 12.0             UNIDADES
# 5                 ALMEIRÃO                 12.0             UNIDADES
# 6   BRÓCOLOS NINJA/JAPONÊS                 12.0             UNIDADES
# 7          BRÓCOLOS RAMOSO                 12.0             UNIDADES
# 8           COUVE-MANTEIGA                 12.0             UNIDADES
# 9               COUVE-FLOR                 12.0             UNIDADES
# 10                ESCAROLA                 12.0             UNIDADES
# 11               ESPINAFRE                 12.0             UNIDADES
# 12                RABANETE                 12.0                MAÇOS
# 13            REPOLHO ROXO                 12.0             UNIDADES
# 14           REPOLHO VERDE                 12.0             UNIDADES
# 15                  RÚCULA                 12.0             UNIDADES
# 16               CEBOLINHA                  0.5                   KG
# 17                 COENTRO                  2.0                   KG
# 18                SALSINHA                  2.0                   KG
# 19         ABOBORÁ CABOTIÁ                 30.0                   KG
# 20      ABOBRINHA ITALIANA                 17.0                   KG
# 21             BATATA-DOCE                 18.0                   KG
# 22         BERINJELA COMUM                 10.0                   KG
# 23      BERINJELA JAPONESA                 10.0                   KG
# 24               BETERRABA                 20.0                   KG
# 25                 CENOURA                 18.0                   KG
# 26                  CHUCHU                 18.0                   KG
# 27                    JILÓ                 17.0                   KG
# 28                MANDIOCA                 18.0                   KG
# 29            PEPINO COMUM                 17.0                   KG
# 30          PEPINO JAPONÊS                 17.0                   KG
# 31          PIMENTÃO VERDE                 10.0                   KG
# 32                  QUIABO                 12.0                   KG
# 33           TOMATE DÉBORA                 17.0                   KG
# 34          VAGEM MACARRÃO                 17.0                   KG
# 35              CAQUI FUYU                 10.0                   KG
# 36            CAQUI GUIMBO                 10.0                   KG
# 37        CAQUI RAMA FORTE                 10.0                   KG
# 38                  GOIABA                 10.0                   KG
# 39         MEXERICA POLKAN                 22.0                   KG
#
#     QTD UNI MED_produtos DESC UNI MED_produtos  QTD_CORRESPONDE  \
# 0                   12.0              UNIDADES             True
# 1                   12.0              UNIDADES             True
# 2                   12.0              UNIDADES             True
# 3                   12.0              UNIDADES             True
# 4                   12.0              UNIDADES             True
# 5                   12.0              UNIDADES             True
# 6                   12.0              UNIDADES             True
# 7                   12.0              UNIDADES             True
# 8                   12.0              UNIDADES             True
# 9                   12.0              UNIDADES             True
# 10                  12.0              UNIDADES             True
# 11                  12.0              UNIDADES             True
# 12                  12.0                 MAÇOS             True
# 13                  12.0              UNIDADES             True
# 14                  12.0              UNIDADES             True
# 15                  12.0              UNIDADES             True
# 16                   0.5                    KG             True
# 17                   2.0                    KG             True
# 18                   2.0                    KG             True
# 19                  30.0                    KG             True
# 20                  17.0                    KG             True
# 21                  18.0                    KG             True
# 22                  10.0                    KG             True
# 23                  10.0                    KG             True
# 24                  20.0                    KG             True
# 25                  18.0                    KG             True
# 26                  18.0                    KG             True
# 27                  17.0                    KG             True
# 28                  18.0                    KG             True
# 29                  17.0                    KG             True
# 30                  17.0                    KG             True
# 31                  10.0                    KG             True
# 32                  12.0                    KG             True
# 33                  17.0                    KG             True
# 34                  17.0                    KG             True
# 35                  10.0                    KG             True
# 36                  10.0                    KG             True
# 37                  10.0                    KG             True
# 38                  10.0                    KG             True
# 39                  22.0                    KG             True
#
#     DESC_CORRESPONDE
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True
# 20              True
# 21              True
# 22              True
# 23              True
# 24              True
# 25              True
# 26              True
# 27              True
# 28              True
# 29              True
# 30              True
# 31              True
# 32              True
# 33              True
# 34              True
# 35              True
# 36              True
# 37              True
# 38              True
# 39              True

# %%
# Resultado com discrepâncias
discrepancias = comparacao[
    ~comparacao['QTD_CORRESPONDE'] | ~comparacao['DESC_CORRESPONDE']
]

# %%
# Exibindo discrepâncias
print("Discrepâncias encontradas:")
display(discrepancias)
# Out:
# Discrepâncias encontradas:
# Empty DataFrame
# Columns: [PRODUTO, QTD UNI MED_boletim, DESC UNI MED_boletim, QTD UNI MED_produtos, DESC UNI MED_produtos, QTD_CORRESPONDE, DESC_CORRESPONDE]
# Index: []

# %% [markdown]
# ### Save Excel file into reports directory
#
# Save an Excel file with intermediate results into the report directory

# %%
df_blt.to_excel(report_file, index=False)
